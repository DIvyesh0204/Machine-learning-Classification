# %%
import sklearn

# %%
## Identify music genre

# %%
import pandas as pd

# %%
train_data= pd.read_csv("music_train.csv")

# %%
train_data.head()
# Out:
#    id  release_date    dating  violence  world/life  night/time  \
# 0   0        2014.0  0.001049  0.000254    0.078057    0.282523
# 1   1        1962.0  0.059132       NaN         NaN    0.001836
# 2   2        1969.0  0.027451  0.085989    0.039760    0.001288
# 3   3        2004.0  0.050993       NaN    0.000000    0.000477
# 4   4        1992.0  0.000551  0.028702    0.000000    0.069748
#
#    shake the audience  family/gospel  romantic  communication  ...  feelings  \
# 0            0.000000       0.000654  1.109899       3.484935  ...  0.001021
# 1            0.000737       0.000000  0.758840       0.000000  ...  0.001697
# 2            0.001424       0.000857  0.545408       0.016914  ...  0.000000
# 3            0.008157       0.002800  0.000000       0.003703  ...  0.067061
# 4            0.008735       0.000625  0.014364       0.253022  ...  0.000000
#
#    danceability  loudness  acousticness  instrumentalness   valence  \
# ...

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17743 entries, 0 to 17742
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id                        17743 non-null  int64
#  1   release_date              16867 non-null  float64
#  2   dating                    16880 non-null  float64
#  3   violence                  16865 non-null  float64
#  4   world/life                16815 non-null  float64
#  5   night/time                16835 non-null  float64
#  6   shake the audience        16828 non-null  float64
#  7   family/gospel             16804 non-null  float64
#  8   romantic                  16841 non-null  float64
#  9   communication             16836 non-null  float64
#  10  obscene                   16867 non-null  float64
#  11  music                     16907 non-null  float64
#  12  movement/places           16858 non-null  float64
# ...

# %%
corr_matrix=train_data.corr()

# %%
corr_matrix['music'].sort_values(ascending=False)
# Out:
# music                       1.000000
# family/spiritual            0.699345
# family/gospel               0.698529
# shake the audience          0.696559
# dating                      0.687420
# like/girls                  0.672619
# feelings                    0.651024
# light/visual perceptions    0.648286
# movement/places             0.606153
# romantic                    0.595854
# night/time                  0.558981
# communication               0.528483
# instrumentalness            0.425986
# sadness                     0.387914
# obscene                     0.382579
# world/life                  0.374139
# violence                    0.349452
# acousticness                0.317512
# danceability                0.223402
# age                         0.215572
# valence                     0.181012
# loudness                    0.156324
# energy                      0.079360
# id                          0.005653
# genre                      -0.047214
# ...

# %%
from pandas.plotting import scatter_matrix
attribute= ["music","family/spiritual","family/gospel","dating"]
scatter_matrix(train_data[attribute],figsize=(12,10))
# Out:
# array([[<AxesSubplot:xlabel='music', ylabel='music'>,
#         <AxesSubplot:xlabel='family/spiritual', ylabel='music'>,
#         <AxesSubplot:xlabel='family/gospel', ylabel='music'>,
#         <AxesSubplot:xlabel='dating', ylabel='music'>],
#        [<AxesSubplot:xlabel='music', ylabel='family/spiritual'>,
#         <AxesSubplot:xlabel='family/spiritual', ylabel='family/spiritual'>,
#         <AxesSubplot:xlabel='family/gospel', ylabel='family/spiritual'>,
#         <AxesSubplot:xlabel='dating', ylabel='family/spiritual'>],
#        [<AxesSubplot:xlabel='music', ylabel='family/gospel'>,
#         <AxesSubplot:xlabel='family/spiritual', ylabel='family/gospel'>,
#         <AxesSubplot:xlabel='family/gospel', ylabel='family/gospel'>,
#         <AxesSubplot:xlabel='dating', ylabel='family/gospel'>],
#        [<AxesSubplot:xlabel='music', ylabel='dating'>,
#         <AxesSubplot:xlabel='family/spiritual', ylabel='dating'>,
# ...
